# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
summary_city_df = pd.read_csv('data/car_sales/summary_all_city.csv')
summary_city_df.head(10)
# Out:
#             City  Number of Listings  Average Price  Average Year  \
# 0        Atlanta                1582       23417.04          2013
# 1        Chicago                3354       19512.84          2013
# 2        Houston               12701       23498.90          2013
# 3          Miami                5250       22489.01          2014
# 4    Minneapolis                  55       21066.01          2012
# 5      Nashville                1888       19096.75          2012
# 6       New York                 450       49833.48          2015
# 7    San Antonio                8078       23300.76          2014
# 8        Seattle                1524       24261.92          2012
# 9  San Francisco                 439       25395.33          2014
#
#    Average Mileage
# 0            52539
# 1            44756
# 2            52352
# 3            35477
# 4            67946
# 5            63148
# 6            24405
# 7            44020
# 8            51945
# 9            28734

# %%
x = summary_city_df['City'].head(10)

# %%
data = summary_city_df['Average Price'].head(10)

# %%
plt.bar(x,data); plt.xticks(x, ('Atl','Chi','Hou','Mia','Minn','Nash','NY','SA', 'Sea','SF'))
plt.xticks(rotation=0)
plt.xlabel("City")
plt.title("Average Price Per City")
plt.ylabel("Average Price")
# Out:
# <img src="data:image/png;base64,..." width="606.3157970819448">
# Text(0, 0.5, 'Average Price')

# %%
x = summary_city_df['City'].head(10)

# %%
data = summary_city_df['Average Year'].head(10)

# %%
plt.bar(x,data); plt.xticks(x, ('Atl','Chi','Hou','Mia','Minn','Nash','NY','SA', 'Sea','SF'))
plt.xticks(rotation=0)
plt.xlabel("City")
plt.title("Average Year Per City")
plt.ylabel("Average Year")
# Out:
# <img src="data:image/png;base64,..." width="606.3157970819448">
# Text(0, 0.5, 'Average Year')

# %%
x = summary_city_df['City'].head(10)

# %%
data = summary_city_df['Average Mileage'].head(10)

# %%
plt.bar(x,data); plt.xticks(x, ('Atl','Chi','Hou','Mia','Minn','Nash','NY','SA', 'Sea','SF'))
plt.xticks(rotation=0)
plt.xlabel("City")
plt.title("Average Mileage Per City")
plt.ylabel("Average Mileage")
# Out:
# <img src="data:image/png;base64,..." width="606.3157970819448">
# Text(0, 0.5, 'Average Mileage')
